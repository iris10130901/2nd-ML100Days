# %% [markdown]
# # 作業1

# %%
1.我們選取了「黑色星期五」這個data，想透過消費者行為進行研究。

# %%
2.資料是從零售商店中的交易紀錄，商店希望從交易紀錄中，針對不同的產品類別，去了解顧客的購買行為。共有55萬筆數據，提供者是Mehdi Dagdoug。

# %%
3.資料型態中的類別型資料為客戶id、產品id、性別、年齡、職業類別、城市類別、居住再現居城市幾年、婚姻狀況、購買產品類別。
連續型資料為購買金額。

# %%
4.將資料進行分群，分成2群，隨機取70%資料為測試資料，剩下的30%為預測資料，把測試資料先帶入變異數分析中，取p值<0.01的因子，放入迴歸分析中，最後再將預測資料帶入進行驗算，去進行評估。

# %% [markdown]
# # 作業2

# %%
1.降低空車率。
首先乘客使用app先輸入起點與終點，在地圖上可見此距離，司機同時也可以看到附近的乘客有乘車需求，司機可以先載第一個乘客，再順路去載其他有需求的乘客，降低空車率
減少花費的時間。
蒐集地圖的距離資料(經緯度)及等待紅綠燈的時間，算出最快可抵達時間。

# %%
2.與google map和交通部合作。

# %%
3.連續型資料int：距離、經緯度、紅綠燈閃爍時間、空車時間 皆為double。

# %%
4.找出最大及最小空車時間，找出乘車地點及紅綠燈等待長短；去探討空車率與乘客滿意度、紅綠燈等待時間等因素是否會影響空車率。

# %% [markdown]
# # 作業3

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
def mean_absolute_error(y, yp):
    """
    計算 MAE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MAE
    """
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

MAE = mean_absolute_error(y, y_hat)
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean absolute error is 10.659
